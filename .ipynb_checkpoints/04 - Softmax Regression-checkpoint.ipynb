# %% [markdown]
# # Softmax Regression
# - Install Keras from PyPI (recommended):
# ```
# pip install keras==2.1.5```

# %%
# %matplotlib inline
import keras
print('Keras version : %s' % keras.__version__)
# Out:
# Using TensorFlow backend.
# Keras version : 2.1.5

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import model_from_json
from PIL import Image
import pandas as pd

from matplotlib import pyplot as plt
from IPython.display import clear_output

# %%
batch_size = 128
nb_classes = 10
nb_epoch = 3

# %%
# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
Y_Train = np_utils.to_categorical(y_train, nb_classes)
Y_Test = np_utils.to_categorical(y_test, nb_classes)

# %%
# Logistic regression model
model = Sequential()
model.add(Dense(10, input_shape=(784,), kernel_initializer ='normal', activation='softmax'))
model.compile(optimizer=SGD(lr=0.05), loss='categorical_crossentropy', metrics=['accuracy', 'mean_squared_error'])

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train
# > val_loss is the value of cost function for your cross validation data 
#   and loss is the value of cost function for your training data
history = model.fit(X_train, Y_Train, 
                    nb_epoch=nb_epoch, validation_data=(X_test, Y_Test), 
                    batch_size=batch_size, verbose=1)
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/keras/models.py:942: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/3
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.7204 - acc: 0.8292 - mean_squared_error: 0.0311 - val_loss: 0.4484 - val_acc: 0.8863 - val_mean_squared_error: 0.0193
# Epoch 2/3
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4303 - acc: 0.8857 - mean_squared_error: 0.0186 - val_loss: 0.3794 - val_acc: 0.8990 - val_mean_squared_error: 0.0163
# Epoch 3/3
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.3845 - acc: 0.8955 - mean_squared_error: 0.0167 - val_loss: 0.3515 - val_acc: 0.9041 - val_mean_squared_error: 0.0151

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_mean_squared_error', 'loss', 'acc', 'mean_squared_error'])

# %%
# Evaluate
evaluation = model.evaluate(X_test, Y_Test, verbose=1)
print('Summary: Loss over the test dataset: %.2f, Accuracy: %.2f' % (evaluation[0], evaluation[1]))
# Out:
# 10000/10000 [==============================] - 0s 44us/step
# Summary: Loss over the test dataset: 0.06, Accuracy: 0.98

# %%
# serialize model to JSON
model_json = model.to_json()
with open("./data/04/04_softmax_regression.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("./data/04/04_softmax_regression.h5")
#print (model.get_weights())
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# evaluate loaded model on test data
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
score = model.evaluate(X_test, Y_Test, verbose=1)
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# 10000/10000 [==============================] - 1s 58us/step
# acc: 98.15%

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img_load = mpimg.imread('./media/MNIST Test/test3.png')
imgplot = plt.imshow(img_load)

# %%
from scipy.misc import imread
import numpy as np

x = imread('./media/MNIST Test/test3.png',mode='L')
#compute a bit-wise inversion so black becomes white and vice versa
print(x.shape)
x = np.invert(x)
x = x.reshape(1,784).astype('float32') / 255

# Example of a train picture
#plt.imshow(X_train[7].reshape(28,28))
#x = X_train[7].reshape(1,784)
#perform the prediction
#model = load_model('02_logistic_regression.h5')
out = model.predict(x)
print(np.argmax(out))
# Out:
# (28, 28)
# 3
